# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from scipy.stats import pearsonr
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
import matplotlib.pyplot as plt
from pprint import pp
import seaborn as sns

# %%
##NEWSPAPERS IDEOLOGY
newspaper_ideo_df = pd.read_csv("news_ideo_over_time.csv", keep_default_na=False)
#newspaper_ideo_df.rename({"published_date": "date"}, inplace=True, axis=1)
print(f'{newspaper_ideo_df["newspaper_ideo"].unique() = }')
print(newspaper_ideo_df.head())

## DEBATES
debates_df = pd.read_csv("speeches_per_date_party.csv", keep_default_na=False)
debates_df = debates_df.replace(    {"current_party": {
            "Centre": "Centre_parties"}})
print(debates_df.shape)
print(debates_df.head())
# check parties
print(f'{debates_df["current_party"].unique() = }')
# Out:
# newspaper_ideo_df["newspaper_ideo"].unique() = array(['Centre', 'Left-wing', 'Right-wing'], dtype=object)
#          date newspaper_ideo  POSITIVE  NEGATIVE
# 0  2021-11-01         Centre         0         1
# 1  2021-11-01      Left-wing         0         1
# 2  2021-11-01     Right-wing         1         3
# 3  2021-11-02         Centre         0         1
# 4  2021-11-02      Left-wing         1         0
# (1431, 4)
#          date   current_party  POSITIVE  NEGATIVE
# 0  2021-11-01  Centre_parties         0         0
# 1  2021-11-01    Conservative         1         1
# 2  2021-11-01          Labour         0         0
# 3  2021-11-02  Centre_parties         0         0
# 4  2021-11-02    Conservative         1         0
# debates_df["current_party"].unique() = array(['Centre_parties', 'Conservative', 'Labour'], dtype=object)

# %%
# reshape data to create a column per party/newspaper
## newspapers
newspaper_ideo_pivot = newspaper_ideo_df.pivot_table(
    values=("NEGATIVE", "POSITIVE"),
    index=["date"],
    columns=["newspaper_ideo"],
    aggfunc="sum",
)
# flatten
newspaper_ideo_pivot.columns = newspaper_ideo_pivot.columns.to_flat_index()
newspaper_ideo_pivot.reset_index(inplace=True)

print(newspaper_ideo_pivot.head(2))

## debates
debates_df_pivot = debates_df.pivot_table(
    values=("NEGATIVE", "POSITIVE"),
    index=["date"],
    columns=["current_party"],
    aggfunc="sum",
)
# flatten
debates_df_pivot.columns = debates_df_pivot.columns.to_flat_index()
newspaper_ideo_pivot.reset_index(inplace=True)

print(debates_df_pivot.head(2))
# Out:
#          date  (NEGATIVE, Centre)  (NEGATIVE, Left-wing)  \
# 0  2021-11-01                   1                      1
# 1  2021-11-02                   1                      0
#
#    (NEGATIVE, Right-wing)  (POSITIVE, Centre)  (POSITIVE, Left-wing)  \
# 0                       3                   0                      0
# 1                       4                   0                      1
#
#    (POSITIVE, Right-wing)
# 0                       1
# 1                       0
#             (NEGATIVE, Centre_parties)  (NEGATIVE, Conservative)  \
# date
# 2021-11-01                           0                         1
# 2021-11-02                           0                         0
#
#             (NEGATIVE, Labour)  (POSITIVE, Centre_parties)  \
# date
# 2021-11-01                   0                           0
# 2021-11-02                   0                           0
#
#             (POSITIVE, Conservative)  (POSITIVE, Labour)
# date
# 2021-11-01                         1                   0
# 2021-11-02                         1                   0

# %%
## Joined on the newspaper dataset because lower max date
merged_df = newspaper_ideo_pivot.merge(
    debates_df_pivot, on="date", how="left", suffixes=("_newspapers", "_debates")
)
#fix date as index
#merged_df.set_index("date", inplace=True)
merged_df = merged_df.drop('index', inplace=False, axis=1)

#fix colnames
merged_df.columns = [ "_".join(x) if type(x) == tuple else x for x in merged_df.columns]
print(merged_df.shape)
print(merged_df.head(2))
# Out:
# (477, 13)
#          date  NEGATIVE_Centre  NEGATIVE_Left-wing  NEGATIVE_Right-wing  \
# 0  2021-11-01                1                   1                    3
# 1  2021-11-02                1                   0                    4
#
#    POSITIVE_Centre  POSITIVE_Left-wing  POSITIVE_Right-wing  \
# 0                0                   0                    1
# 1                0                   1                    0
#
#    NEGATIVE_Centre_parties  NEGATIVE_Conservative  NEGATIVE_Labour  \
# 0                        0                      1                0
# 1                        0                      0                0
#
#    POSITIVE_Centre_parties  POSITIVE_Conservative  POSITIVE_Labour
# 0                        0                      1                0
# 1                        0                      1                0

# %%
merged_df["date"] = pd.to_datetime(merged_df["date"])
start_winter = pd.to_datetime("2022-11-20")
end_winter = pd.to_datetime("2023-02-10")
merged_df = merged_df[(merged_df['date'] >= start_winter) & (merged_df['date'] <= end_winter)]

merged_df.set_index("date", inplace=True)
print(merged_df.head())
# Out:
#             NEGATIVE_Centre  NEGATIVE_Left-wing  NEGATIVE_Right-wing  \
# date
# 2022-11-20                3                   2                    1
# 2022-11-21                3                   0                    1
# 2022-11-22                5                   2                    6
# 2022-11-23               10                  11                   14
# 2022-11-24                8                   4                    8
#
#             POSITIVE_Centre  POSITIVE_Left-wing  POSITIVE_Right-wing  \
# date
# 2022-11-20                2                   1                    1
# 2022-11-21                3                   1                    0
# 2022-11-22                0                   1                    1
# 2022-11-23                4                   2                    3
# 2022-11-24                3                   1                    0
#
#             NEGATIVE_Centre_parties  NEGATIVE_Conservative  NEGATIVE_Labour  \
# date
# 2022-11-20                        0                      0                0
# 2022-11-21                        1                      0                1
# 2022-11-22                        0                      2                3
# 2022-11-23                        1                      0                0
# 2022-11-24                        0                      4                1
#
#             POSITIVE_Centre_parties  POSITIVE_Conservative  POSITIVE_Labour
# date
# 2022-11-20                        0                      0                0
# 2022-11-21                        0                      0                0
# 2022-11-22                        1                      1                2
# 2022-11-23                        0                      1                0
# 2022-11-24                        0                      2                1

# %%
# Stationarity function
def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)
    for key,val in result[4].items():
        out[f'critical value ({key})']=val
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
# Differencing
adf_test(merged_df["NEGATIVE_Centre"])

merged_df_diff = merged_df.diff()
merged_df_diff = merged_df_diff.iloc[1:]
adf_test(merged_df_diff["NEGATIVE_Centre"])
print(merged_df_diff.head(2))
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic      -5.310954
# p-value                  0.000005
# # lags used              0.000000
# # observations          82.000000
# critical value (1%)     -3.512738
# critical value (5%)     -2.897490
# critical value (10%)    -2.585949
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
# Augmented Dickey-Fuller Test:
# ADF test statistic     -6.756195e+00
# p-value                 2.867712e-09
# # lags used             5.000000e+00
# # observations          7.600000e+01
# critical value (1%)    -3.519481e+00
# critical value (5%)    -2.900395e+00
# critical value (10%)   -2.587498e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#             NEGATIVE_Centre  NEGATIVE_Left-wing  NEGATIVE_Right-wing  \
# date
# 2022-11-21              0.0                -2.0                  0.0
# 2022-11-22              2.0                 2.0                  5.0
#
#             POSITIVE_Centre  POSITIVE_Left-wing  POSITIVE_Right-wing  \
# date
# 2022-11-21              1.0                 0.0                 -1.0
# 2022-11-22             -3.0                 0.0                  1.0
#
#             NEGATIVE_Centre_parties  NEGATIVE_Conservative  NEGATIVE_Labour  \
# date
# 2022-11-21                      1.0                    0.0              1.0
# 2022-11-22                     -1.0                    2.0              2.0
#
#             POSITIVE_Centre_parties  POSITIVE_Conservative  POSITIVE_Labour
# date
# 2022-11-21                      0.0                    0.0              0.0
# 2022-11-22                      1.0                    1.0              2.0

# %%
# Determine lags
plot_pacf(merged_df_diff["NEGATIVE_Left-wing"], method = "ols", lags = 30)
plt.show()
## lag 6 

plot_pacf(merged_df_diff["POSITIVE_Right-wing"], method = "ols", lags = 30)
plt.show()

plot_pacf(merged_df_diff["NEGATIVE_Conservative"], method = "ols", lags = 30)
plt.show()

plot_pacf(merged_df_diff["NEGATIVE_Labour"], method = "ols", lags = 30)
plt.show()
## lag 6

# %%
corr_matrix = merged_df.corr()

# Print the correlation matrix
pp(corr_matrix)

sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt='.2f')

# Show the plot
plt.show()
# Out:
#                          NEGATIVE_Centre  NEGATIVE_Left-wing  \
# NEGATIVE_Centre                 1.000000            0.553214
# NEGATIVE_Left-wing              0.553214            1.000000
# NEGATIVE_Right-wing             0.673594            0.549120
# POSITIVE_Centre                 0.464308            0.278409
# POSITIVE_Left-wing              0.365778            0.186840
# POSITIVE_Right-wing             0.207286            0.268064
# NEGATIVE_Centre_parties         0.130570            0.144593
# NEGATIVE_Conservative           0.176353            0.220302
# NEGATIVE_Labour                 0.176053            0.173198
# POSITIVE_Centre_parties         0.163348            0.205436
# POSITIVE_Conservative           0.187752            0.203749
# POSITIVE_Labour                 0.130716            0.084272
#
#                          NEGATIVE_Right-wing  POSITIVE_Centre  \
# NEGATIVE_Centre                     0.673594         0.464308
# NEGATIVE_Left-wing                  0.549120         0.278409
# NEGATIVE_Right-wing                 1.000000         0.219271
# POSITIVE_Centre                     0.219271         1.000000
# POSITIVE_Left-wing                  0.322234         0.292870
# POSITIVE_Right-wing                 0.252498         0.292463
# NEGATIVE_Centre_parties            -0.063231         0.127507
# NEGATIVE_Conservative              -0.011742         0.250645
# NEGATIVE_Labour                    -0.069410         0.167152
# POSITIVE_Centre_parties             0.033778         0.175426
# POSITIVE_Conservative              -0.022317         0.221221
# POSITIVE_Labour                    -0.092473         0.143415
#
#                          POSITIVE_Left-wing  POSITIVE_Right-wing  \
# NEGATIVE_Centre                    0.365778             0.207286
# NEGATIVE_Left-wing                 0.186840             0.268064
# NEGATIVE_Right-wing                0.322234             0.252498
# POSITIVE_Centre                    0.292870             0.292463
# POSITIVE_Left-wing                 1.000000             0.100040
# POSITIVE_Right-wing                0.100040             1.000000
# NEGATIVE_Centre_parties            0.005457            -0.054580
# NEGATIVE_Conservative              0.028390            -0.067566
# NEGATIVE_Labour                   -0.030753            -0.040639
# POSITIVE_Centre_parties            0.129773             0.129177
# POSITIVE_Conservative             -0.012348            -0.023443
# POSITIVE_Labour                   -0.014118            -0.117944
#
#                          NEGATIVE_Centre_parties  NEGATIVE_Conservative  \
# NEGATIVE_Centre                         0.130570               0.176353
# NEGATIVE_Left-wing                      0.144593               0.220302
# NEGATIVE_Right-wing                    -0.063231              -0.011742
# POSITIVE_Centre                         0.127507               0.250645
# POSITIVE_Left-wing                      0.005457               0.028390
# POSITIVE_Right-wing                    -0.054580              -0.067566
# NEGATIVE_Centre_parties                 1.000000               0.900998
# NEGATIVE_Conservative                   0.900998               1.000000
# NEGATIVE_Labour                         0.924422               0.921593
# POSITIVE_Centre_parties                 0.711650               0.693453
# POSITIVE_Conservative                   0.793082               0.902364
# POSITIVE_Labour                         0.859206               0.788941
#
#                          NEGATIVE_Labour  POSITIVE_Centre_parties  \
# NEGATIVE_Centre                 0.176053                 0.163348
# NEGATIVE_Left-wing              0.173198                 0.205436
# NEGATIVE_Right-wing            -0.069410                 0.033778
# POSITIVE_Centre                 0.167152                 0.175426
# POSITIVE_Left-wing             -0.030753                 0.129773
# POSITIVE_Right-wing            -0.040639                 0.129177
# NEGATIVE_Centre_parties         0.924422                 0.711650
# NEGATIVE_Conservative           0.921593                 0.693453
# NEGATIVE_Labour                 1.000000                 0.680351
# POSITIVE_Centre_parties         0.680351                 1.000000
# POSITIVE_Conservative           0.927795                 0.629618
# POSITIVE_Labour                 0.825972                 0.753133
#
#                          POSITIVE_Conservative  POSITIVE_Labour
# NEGATIVE_Centre                       0.187752         0.130716
# NEGATIVE_Left-wing                    0.203749         0.084272
# NEGATIVE_Right-wing                  -0.022317        -0.092473
# POSITIVE_Centre                       0.221221         0.143415
# POSITIVE_Left-wing                   -0.012348        -0.014118
# POSITIVE_Right-wing                  -0.023443        -0.117944
# NEGATIVE_Centre_parties               0.793082         0.859206
# NEGATIVE_Conservative                 0.902364         0.788941
# NEGATIVE_Labour                       0.927795         0.825972
# POSITIVE_Centre_parties               0.629618         0.753133
# POSITIVE_Conservative                 1.000000         0.695785
# POSITIVE_Labour                       0.695785         1.000000

# %%
model = VAR(merged_df_diff)
model_fit = model.fit(maxlags=5, ic="aic")
model_fit.summary()
# Out:
# /home/debian/miniconda3/envs/debates/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 09, May, 2023
# Time:                     08:42:58
# --------------------------------------------------------------------
# No. of Equations:         12.0000    BIC:                    33.4994
# Nobs:                     77.0000    HQIC:                   20.1303
# Log likelihood:          -1010.99    FPE:                6.97885e+07
# AIC:                      11.2180    Det(Omega_mle):         63551.2
# --------------------------------------------------------------------
# Results for equation NEGATIVE_Centre
# =============================================================================================
#                                 coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------
# const                             -0.104713         0.454231           -0.231           0.818
# L1.NEGATIVE_Centre                -0.026013         0.260978           -0.100           0.921
# L1.NEGATIVE_Left-wing              0.416506         0.374780            1.111           0.266
# L1.NEGATIVE_Right-wing            -0.112408         0.249209           -0.451           0.652
# L1.POSITIVE_Centre                 0.144517         0.274983            0.526           0.599
# L1.POSITIVE_Left-wing             -0.134836         0.834071           -0.162           0.872
# L1.POSITIVE_Right-wing            -0.442377         0.400761           -1.104           0.270
# L1.NEGATIVE_Centre_parties         0.957875         1.045144            0.917           0.359
# L1.NEGATIVE_Conservative           0.683577         0.434876            1.572           0.116
# L1.NEGATIVE_Labour                -0.597347         0.420700           -1.420           0.156
# L1.POSITIVE_Centre_parties         3.570666         2.293304            1.557           0.119
# L1.POSITIVE_Conservative          -0.111197         0.324340           -0.343           0.732
# L1.POSITIVE_Labour                -0.834319         0.976804           -0.854           0.393
# L2.NEGATIVE_Centre                -0.485578         0.317764           -1.528           0.126
# L2.NEGATIVE_Left-wing             -1.007178         0.656345           -1.535           0.125
# L2.NEGATIVE_Right-wing             0.456556         0.374494            1.219           0.223
# L2.POSITIVE_Centre                -0.013487         0.263373           -0.051           0.959
# L2.POSITIVE_Left-wing             -0.058969         0.879934           -0.067           0.947
# L2.POSITIVE_Right-wing            -0.303095         0.449631           -0.674           0.500
# L2.NEGATIVE_Centre_parties         0.116111         1.092052            0.106           0.915
# L2.NEGATIVE_Conservative           0.613634         0.700327            0.876           0.381
# L2.NEGATIVE_Labour                -0.217523         0.589542           -0.369           0.712
# L2.POSITIVE_Centre_parties         1.226435         1.846708            0.664           0.507
# L2.POSITIVE_Conservative          -0.134612         0.487162           -0.276           0.782
# L2.POSITIVE_Labour                 0.662242         1.288960            0.514           0.607
# L3.NEGATIVE_Centre                -0.307504         0.271966           -1.131           0.258
# L3.NEGATIVE_Left-wing             -0.398628         0.450922           -0.884           0.377
# L3.NEGATIVE_Right-wing             0.186439         0.401186            0.465           0.642
# L3.POSITIVE_Centre                 0.280304         0.387819            0.723           0.470
# L3.POSITIVE_Left-wing              0.253019         0.960229            0.263           0.792
# L3.POSITIVE_Right-wing             0.043512         0.592488            0.073           0.941
# L3.NEGATIVE_Centre_parties        -0.092997         1.003923           -0.093           0.926
# L3.NEGATIVE_Conservative           0.781942         0.759802            1.029           0.303
# L3.NEGATIVE_Labour                -0.219330         0.691964           -0.317           0.751
# L3.POSITIVE_Centre_parties         2.252765         2.129974            1.058           0.290
# L3.POSITIVE_Conservative          -0.274096         0.637298           -0.430           0.667
# L3.POSITIVE_Labour                 0.030151         1.217594            0.025           0.980
# L4.NEGATIVE_Centre                -0.117386         0.207557           -0.566           0.572
# L4.NEGATIVE_Left-wing             -0.421032         0.498916           -0.844           0.399
# L4.NEGATIVE_Right-wing             0.473369         0.287572            1.646           0.100
# L4.POSITIVE_Centre                 0.571375         0.608227            0.939           0.348
# L4.POSITIVE_Left-wing              0.054684         1.264306            0.043           0.966
# L4.POSITIVE_Right-wing            -0.854439         0.600958           -1.422           0.155
# L4.NEGATIVE_Centre_parties         0.872881         0.834415            1.046           0.296
# L4.NEGATIVE_Conservative          -0.017562         0.723087           -0.024           0.981
# L4.NEGATIVE_Labour                -0.104845         0.648215           -0.162           0.872
# L4.POSITIVE_Centre_parties         2.759996         2.633927            1.048           0.295
# L4.POSITIVE_Conservative          -0.127406         0.465641           -0.274           0.784
# L4.POSITIVE_Labour                -0.941820         1.228232           -0.767           0.443
# L5.NEGATIVE_Centre                -0.360470         0.186621           -1.932           0.053
# L5.NEGATIVE_Left-wing             -0.545915         0.648877           -0.841           0.400
# L5.NEGATIVE_Right-wing             0.354385         0.191256            1.853           0.064
# L5.POSITIVE_Centre                 0.069731         0.281533            0.248           0.804
# L5.POSITIVE_Left-wing              1.009790         0.732612            1.378           0.168
# L5.POSITIVE_Right-wing             0.505895         0.525779            0.962           0.336
# L5.NEGATIVE_Centre_parties        -0.434247         0.793968           -0.547           0.584
# L5.NEGATIVE_Conservative           0.480203         0.642050            0.748           0.455
# L5.NEGATIVE_Labour                 0.318092         0.458639            0.694           0.488
# L5.POSITIVE_Centre_parties        -2.147969         3.085208           -0.696           0.486
# L5.POSITIVE_Conservative          -0.528092         0.330193           -1.599           0.110
# L5.POSITIVE_Labour                 0.290397         1.300793            0.223           0.823
# =============================================================================================
#
# Results for equation NEGATIVE_Left-wing
# =============================================================================================
#                                 coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------
# const
# =============================================================================================
#                                 coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------
# const                              0.189155         0.243963            0.775           0.438
# L1.NEGATIVE_Centre                 0.020079         0.140169            0.143           0.886
# L1.NEGATIVE_Left-wing              0.444167         0.201290            2.207           0.027
# L1.NEGATIVE_Right-wing             0.116448         0.133848            0.870           0.384
# L1.POSITIVE_Centre                 0.049717         0.147691            0.337           0.736
# L1.POSITIVE_Left-wing              0.612904         0.447971            1.368           0.171
# L1.POSITIVE_Right-wing            -0.534271         0.215244           -2.482           0.013
# L1.NEGATIVE_Centre_parties         0.102089         0.561335            0.182           0.856
# L1.NEGATIVE_Conservative           0.120261         0.233567            0.515           0.607
# L1.NEGATIVE_Labour                 0.178441         0.225954            0.790           0.430
# L1.POSITIVE_Centre_parties         0.114640         1.231709            0.093           0.926
# L1.POSITIVE_Conservative          -0.243930         0.174200           -1.400           0.161
# L1.POSITIVE_Labour                -1.218159         0.524631           -2.322           0.020
# L2.NEGATIVE_Centre                -0.599331         0.170668           -3.512           0.000
# L2.NEGATIVE_Left-wing             -0.433228         0.352516           -1.229           0.219
# L2.NEGATIVE_Right-wing             0.252603         0.201137            1.256           0.209
# L2.POSITIVE_Centre                -0.184760         0.141455           -1.306           0.192
# L2.POSITIVE_Left-wing              0.640313         0.472603            1.355           0.175
# L2.POSITIVE_Right-wing             0.377661         0.241492            1.564           0.118
# L2.NEGATIVE_Centre_parties        -1.484227         0.586529           -2.531           0.011
# L2.NEGATIVE_Conservative           0.992617         0.376138            2.639           0.008
# L2.NEGATIVE_Labour                 0.720661         0.316637            2.276           0.023
# L2.POSITIVE_Centre_parties        -0.517755         0.991847           -0.522           0.602
# L2.POSITIVE_Conservative          -0.624544         0.261650           -2.387           0.017
# L2.POSITIVE_Labour                -0.963908         0.692286           -1.392           0.164
# L3.NEGATIVE_Centre                -0.235106         0.146070           -1.610           0.107
# L3.NEGATIVE_Left-wing             -0.028212         0.242186           -0.116           0.907
# L3.NEGATIVE_Right-wing             0.404600         0.215473            1.878           0.060
# L3.POSITIVE_Centre                 0.027691         0.208293            0.133           0.894
# L3.POSITIVE_Left-wing             -0.182914         0.515729           -0.355           0.723
# L3.POSITIVE_Right-wing            -0.319377         0.318219           -1.004           0.316
# L3.NEGATIVE_Centre_parties        -1.835830         0.539196           -3.405           0.001
# L3.NEGATIVE_Conservative           0.662554         0.408081            1.624           0.104
# L3.NEGATIVE_Labour                 1.061714         0.371647            2.857           0.004
# L3.POSITIVE_Centre_parties         1.023939         1.143986            0.895           0.371
# L3.POSITIVE_Conservative          -0.804546         0.342286           -2.351           0.019
# L3.POSITIVE_Labour                -0.864036         0.653957           -1.321           0.186
# L4.NEGATIVE_Centre                -0.281685         0.111477           -2.527           0.012
# POSITIVE_Centre_parties          -0.045115            0.275380             0.527459         0.193115           -0.046295            -0.109362                 0.779278               0.550174         0.603138                 1.000000               0.381692         0.716082
# POSITIVE_Conservative             0.223521            0.218293             0.165792         0.362867            0.059259            -0.088380                 0.586296               0.810300         0.873905                 0.381692               1.000000         0.281087
# POSITIVE_Labour                  -0.041197            0.083918             0.155646         0.142873            0.096409            -0.422477                 0.896007               0.573559         0.655507                 0.716082               0.281087         1.000000

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# get only significant p-values
model_pvalues = model_fit.pvalues

print(model_pvalues.columns)
print(model_pvalues.shape)

model_pvalues = model_pvalues.melt(value_vars=model_pvalues.columns, var_name = "y_variable", value_name = "pvalue", ignore_index=False)

print(model_pvalues.head())


model_pvalues = model_pvalues[model_pvalues["pvalue"] < 0.05]
#model_pvalues.dropna(how='all', subset=model_pvalues.columns, inplace=True)
model_pvalues.index.name = "x_variable" 

pp(model_pvalues)

model_pvalues.to_csv("varmodel_3_pvalues_winter.csv", index=True)
# Out:
# Index(['NEGATIVE_Centre', 'NEGATIVE_Left-wing', 'NEGATIVE_Right-wing',
#        'POSITIVE_Centre', 'POSITIVE_Left-wing', 'POSITIVE_Right-wing',
#        'NEGATIVE_Centre_parties', 'NEGATIVE_Conservative', 'NEGATIVE_Labour',
#        'POSITIVE_Centre_parties', 'POSITIVE_Conservative', 'POSITIVE_Labour'],
#       dtype='object')
# (61, 12)
#                              y_variable  pvalue
# const                   NEGATIVE_Centre   0.818
# L1.NEGATIVE_Centre      NEGATIVE_Centre   0.921
# L1.NEGATIVE_Left-wing   NEGATIVE_Centre   0.266
# L1.NEGATIVE_Right-wing  NEGATIVE_Centre   0.652
# L1.POSITIVE_Centre      NEGATIVE_Centre   0.599
#                                    y_variable  pvalue
# x_variable
# L1.NEGATIVE_Left-wing      NEGATIVE_Left-wing   0.049
# L5.POSITIVE_Left-wing      NEGATIVE_Left-wing   0.024
# L1.NEGATIVE_Centre        NEGATIVE_Right-wing   0.014
# L1.NEGATIVE_Right-wing    NEGATIVE_Right-wing   0.029
# L2.NEGATIVE_Right-wing    NEGATIVE_Right-wing   0.043
# ...                                       ...     ...
# L4.NEGATIVE_Right-wing        POSITIVE_Labour   0.009
# L4.POSITIVE_Right-wing        POSITIVE_Labour   0.015
# L4.NEGATIVE_Conservative      POSITIVE_Labour   0.011
# L4.NEGATIVE_Labour            POSITIVE_Labour   0.003
# L4.POSITIVE_Labour            POSITIVE_Labour   0.030
#
# [112 rows x 2 columns]

# %%
sorted_order=model.select_order(maxlags=5)
print(sorted_order.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0       27.76      28.12*   1.135e+12       27.90
# 1       25.70       30.45   1.514e+11       27.60
# 2       24.04       33.17   3.698e+10       27.69
# 3       22.90       36.41   2.480e+10       28.30
# 4       19.59       37.49   5.182e+09       26.75
# 5      11.22*       33.50  6.979e+07*      20.13*
# -------------------------------------------------

# %%
fevd = model_fit.fevd(6)
model_fevd = pd.DataFrame(fevd.summary())

model_fit.fevd(6).plot()
# Out:
# FEVD for NEGATIVE_Centre
#      NEGATIVE_Centre  NEGATIVE_Left-wing  NEGATIVE_Right-wing  POSITIVE_Centre  POSITIVE_Left-wing  POSITIVE_Right-wing  NEGATIVE_Centre_parties  NEGATIVE_Conservative  NEGATIVE_Labour  POSITIVE_Centre_parties  POSITIVE_Conservative  POSITIVE_Labour
# 0
#      NEGATIVE_Centre  NEGATIVE_Left-wing  NEGATIVE_Right-wing  POSITIVE_Centre  POSITIVE_Left-wing  POSITIVE_Right-wing  NEGATIVE_Centre_parties  NEGATIVE_Conservative  NEGATIVE_Labour  POSITIVE_Centre_parties  POSITIVE_Conservative  POSITIVE_Labour
# 0           0.001697            0.010621             0.014938         0.038610            0.026169             0.263318                 0.466292               0.062097         0.024590                 0.020804               0.003097         0.067766
# 1           0.073525            0.086993             0.009842         0.027595            0.036248             0.191175                 0.378069               0.052511         0.014005                 0.023861               0.011677         0.094501
# 2           0.069524            0.114674             0.009188         0.057739            0.031356             0.414167                 0.163253               0.070780         0.006246                 0.012318               0.010405         0.040351
# 3           0.066423            0.103344             0.007597         0.068079            0.026864             0.394104                 0.143167               0.080234         0.014769                 0.035396               0.011133         0.048889
# 4           0.062655            0.112855             0.033096         0.062713            0.021471             0.322637                 0.115923               0.069118         0.038976                 0.051493               0.054465         0.054598
# 5           0.072595            0.112192             0.090048         0.051558            0.019578             0.281187                 0.101429               0.072863         0.042913                 0.058884               0.049420         0.047332

# %%
def granger_causality(data, maxlag):
    """
    Performs Granger causality tests for each variable in a dataset using a specified number of lags.

    Args:
    - data: A pandas DataFrame containing the time series data.
    - maxlag: An integer specifying the maximum number of lags to consider in the Granger causality tests.

    Returns:
    - A pandas DataFrame containing the p-values for each pairwise Granger causality test.
    """

    # Initialize an empty DataFrame to store the p-values
    #p_values = pd.DataFrame(columns=data.columns, index=data.columns)
    results: list[dict] = []
    # Loop through each pair of variables and perform a Granger causality test
    for i in range(len(data.columns)):
        for j in range(len(data.columns)):
            if i != j:
                # Select the two variables to test
                x = data.iloc[:, i]
                y = data.iloc[:, j]

                x_name = data.columns[i]
                y_name = data.columns[j]


                # Run the Granger causality test
                gc_result = grangercausalitytests(np.column_stack((x, y)), maxlag=maxlag, verbose=False)

                # Extract the p-value from the test results for each lag
                #p_values_list = []
                for lag in range(1, maxlag + 1):
                    p_value = gc_result[lag][0]['lrtest'][1]
                    #p_values_list.append(p_value)
                
                # Store the p-values in the DataFrame
                #p_values.iloc[i, j] = str(p_values_list)
                    result = {"x_name":x_name, "y_name":y_name, "lag":lag, "p-value":p_value}

                    results.append(result)

    return pd.DataFrame(results)

# %%
results = granger_causality(merged_df_diff, 5)

print(results)
# Out:
#               x_name                 y_name  lag  p-value
# 0    NEGATIVE_Centre     NEGATIVE_Left-wing    1    0.012
# 1    NEGATIVE_Centre     NEGATIVE_Left-wing    2    0.011
# 2    NEGATIVE_Centre     NEGATIVE_Left-wing    3    0.009
# 3    NEGATIVE_Centre     NEGATIVE_Left-wing    4    0.024
# 4    NEGATIVE_Centre     NEGATIVE_Left-wing    5    0.034
# ..               ...                    ...  ...      ...
# 655  POSITIVE_Labour  POSITIVE_Conservative    1    0.922
# 656  POSITIVE_Labour  POSITIVE_Conservative    2    0.822
# 657  POSITIVE_Labour  POSITIVE_Conservative    3    0.859
# 658  POSITIVE_Labour  POSITIVE_Conservative    4    0.939
# 659  POSITIVE_Labour  POSITIVE_Conservative    5    0.678
#
# [660 rows x 4 columns]
